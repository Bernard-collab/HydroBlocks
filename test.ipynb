# %%
data_rad3d = "/projects/ezorzetto@xsede.org/snow_experiment/experiments/simulations/MSWX_3h_Snow_Project_3/output_data/1/2014-01-01.nc
data_radpp - "/projects/ezorzetto@xsede.org/snow_experiment/experiments/simulations/MSWX_3h_Snow_Project_3_planepar/output_data/1/2014-01-01.nc"
# Out:
#   File "<ipython-input-1-96cdae4fe1f9>", line 1
#     data_rad3d = "/projects/ezorzetto@xsede.org/snow_experiment/experiments/simulations/MSWX_3h_Snow_Project_3/output_data/1/2014-01-01.nc
#                                                                                                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
import xarray as xr
import numpy as np

dspp = xr.open_dataset(data_radpp)

print(dspp)
